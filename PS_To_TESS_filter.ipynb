# %% [markdown]
# # Find PS filter combination that best resembles TESS

# %%
# %matplotlib notebook
import ipympl
import matplotlib.pyplot as plt

import numpy as np
# Out:
# /Users/ryanr/anaconda3/lib/python3.5/site-packages/ipympl/__init__.py:25: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'nbAgg' by the following code:
#   File "/Users/ryanr/anaconda3/lib/python3.5/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/ryanr/anaconda3/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/ryanr/anaconda3/lib/python3.5/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/Users/ryanr/anaconda3/lib/python3.5/asyncio/base_events.py", line 1425, in _run_once
#     handle._run()
#   File "/Users/ryanr/anaconda3/lib/python3.5/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-009516ed91a9>", line 1, in <module>
#     get_ipython().run_line_magic('matplotlib', 'notebook')
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 2131, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py", line 3051, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/IPython/core/pylabtools.py", line 311, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/Users/ryanr/anaconda3/lib/python3.5/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/Users/ryanr/anaconda3/lib/python3.5/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('module://ipympl.backend_nbagg')

# %%
TESS = np.loadtxt('./filters/TESS/TESS.dat')
Kepler = np.loadtxt('./filters/Kepler/Kepler.dat')
PSg = np.loadtxt('./filters/PANSTARRS/PAN-STARRS_PS1_g.dat')
PSr = np.loadtxt('./filters/PANSTARRS/PAN-STARRS_PS1_r.dat')
PSi = np.loadtxt('./filters/PANSTARRS/PAN-STARRS_PS1_i.dat')
PSz = np.loadtxt('./filters/PANSTARRS/PAN-STARRS_PS1_z.dat')
PSy = np.loadtxt('./filters/PANSTARRS/PAN-STARRS_PS1_y.dat')

# %%
# compare throughputs
plt.figure()
plt.plot(TESS[:,0],TESS[:,1],label = 'TESS', rasterized=True)
plt.plot(Kepler[:,0],Kepler[:,1],label = 'Kepler', rasterized=True)
plt.plot(PSg[:,0],PSg[:,1],label = r'PS $g$', rasterized=True)
plt.plot(PSr[:,0],PSr[:,1],label = r'PS $r$', rasterized=True)
plt.plot(PSi[:,0],PSi[:,1],label = r'PS $i$', rasterized=True)
plt.plot(PSz[:,0],PSz[:,1],label = r'PS $z$', rasterized=True)
plt.plot(PSy[:,0],PSy[:,1],label = r'PS $y$', rasterized=True)
plt.xlabel(r'Wavelength $(\AA)$')
plt.ylabel('Throughput')
plt.legend()
plt.title('Comparison of TESS and PS filter throughputs')
plt.savefig('TESS_PS_filters.pdf', dpi=400)
# Out:
# <img src="data:image/png;base64,..." width="599.9999910593034">

# %%
0.6e6
# Out:
# 600000.0
