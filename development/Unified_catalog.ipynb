# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path
sys.path.append('../scenes/')
import syndiff as sd 
from delta_kernal import *

# %%
ra = 189.1385827     
dec = 11.2316599

# %%
scene = sd.Catalog_scene(ra,dec,80,Maglim = 18, Sector=23, Catalog='unified',Interpolate=False,Plot=True)#,Save='PS1_catalog_scene.pdf')
# Out:
#      objID     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  gmag  e_gmag  gKmag  \
# 9804   NaN  188.988297  11.404921        NaN        NaN   NaN     NaN    NaN
#
#       e_gKmag  rmag  ...  ymag  e_ymag  yKmag  e_yKmag    tmag  \
# 9804      NaN   NaN  ...   NaN     NaN    NaN      NaN  8.5279
#
#                    gaiaid  gaiamag  gaiadist  gaiadist_u  gaiadist_l
# 9804  3904527697615028736   9.0279       NaN         NaN         NaN
#
# [1 rows x 31 columns]
# ../scenes/syndiff.py:407: RuntimeWarning: invalid value encountered in less
#   result = result.iloc[result.tmag.values < magnitude_limit]
# 310
# <img src="data:image/png;base64,..." width="799.9999880790713">

# %%
cat = scene['catalog']

# %%
ind = np.where(cat.rmag -cat.rKmag > 0.05)[0]

# %%
gals = cat.iloc[ind]

# %%
gals
# Out:
#                    objID     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 616   121161893342046966  189.334075  10.972026     0.0094     0.0144
# 2082  121131890588855782  189.058986  10.945999     0.1098     0.1491
# 2213  121211890316746711  189.031660  11.013515     0.0093     0.0093
# 2910  121341892602069800  189.260115  11.124391     0.0041     0.0049
# 2950  121321891642902493  189.164229  11.101788     0.0694     0.0526
# 3309  121241890342003799  189.034158  11.036061     0.0068     0.0162
# 3521  121321890002687319  189.000257  11.105649     0.0067     0.0074
# 3885  121461889346962091  188.934668  11.217987     0.0053     0.0053
# 4087  121471891322222177  189.132270  11.226303     0.0225     0.0177
# 4111  121481891372610920  189.137228  11.233587     0.0098     0.0098
# 4122  121511891362680095  189.136249  11.257982     0.0533     0.0409
# 4123  121481891404263956  189.140460  11.236066     0.0100     0.0100
# 4124  121491891454418823  189.145496  11.248577     0.0233     0.0234
# 4125  121481891410377228  189.141090  11.238905     0.0706     0.0688
# 4126  121501891488171539  189.148723  11.250773     0.8256     0.8326
# 4127  121481891484116587  189.148543  11.238138     0.7323     0.6772
# 4129  121471891395416767  189.139506  11.230183     0.0407     0.0210
# 4138  121481891434857698  189.143376  11.239191     0.1293     0.1933
# 4139  121481891427607137  189.142809  11.238845     0.1337     0.0488
# 4147  121491891451140386  189.145017  11.241494     0.0471     0.0429
# 4149  121491891495399840  189.149484  11.249435     0.0463     0.0537
# 4150  121481891396641066  189.139594  11.233810     0.0183     0.0191
# 4153  121491891462559506  189.146439  11.249231     0.1765     0.0851
# 4154  121471891416646839  189.141687  11.230192     0.0336     0.0551
# 4156  121471891431658749  189.143196  11.232024     0.0337     0.0531
# 4157  121491891439306740  189.143908  11.246852     0.0282     0.0251
# 4161  121491891435081472  189.143537  11.242492     0.0536     0.0788
# 4163  121471891409198607  189.140794  11.231901     0.0357     0.0300
# 4164  121491891455723618  189.145545  11.244156     0.0486     0.1060
# 4193  121481892562121848  189.256167  11.234438     0.0066     0.0300
# 4312  121511891435815148  189.143520  11.262176     0.0209     0.0189
# 4474  121511891397485379  189.139721  11.262318     0.0213     0.0221
# 4482  121511891361623066  189.136192  11.260460     0.0086     0.0086
# 4528  121501890346982880  189.034665  11.251925     0.0102     0.0108
# 4538  121521889880179851  188.987997  11.274403     0.0060     0.0059
# 4542  121521889902167160  188.990189  11.272162     0.0072     0.0112
# 4757  121661891532018618  189.153280  11.389942     0.0478     0.0478
# 6164  121801889832621776  188.983280  11.501011     0.0239     0.0121
# 6169  121801889824751243  188.982369  11.500599     0.2003     0.1220
# 7251  121461894243466777  189.424208  11.221953     0.0076     0.0076
# 8159  121681892210906567  189.221052  11.405023     0.0087     0.0151
# 8253  121711891936930833  189.193657  11.425263     0.0057     0.0043
# 8879  121801891519860623  189.151977  11.500094     0.0045     0.0066
# 9177  121821890638349893  189.063849  11.524477     0.0103     0.0143
# 9248  121871890104061374  189.010424  11.559058     0.0081     0.0079
# 9266  121881890380810979  189.038199  11.567023     0.0109     0.0109
#
#          gmag  e_gmag    gKmag  e_gKmag     rmag  ...    yKmag  e_yKmag  \
# 616   18.7207  0.0384  16.2010   0.0024  17.7443  ...  15.1620   0.0155
# 2082  13.4990  0.0076  13.5572   0.0030  12.9349  ...  11.6789   0.0010
# 2213  19.1368  0.0168  19.2116   0.0185  18.3788  ...      NaN      NaN
# 2910  19.1419  0.0191  18.0047   0.0318  17.9375  ...  16.0612   0.0153
# 2950  18.6858  0.0772  16.2927   0.0138  18.2429  ...  16.0185   0.0000
# 3309  19.3684  0.0295  17.6231   0.0096  18.5648  ...  16.4261   0.0170
# 3521  19.5346  0.0282  18.1632   0.0163  18.7440  ...  16.8342   0.0229
# 3885  18.6086  0.0181  18.5551   0.0085  18.3479  ...  17.0699   0.0192
# 4087  19.0933  0.0337  15.4955   0.1255  19.0060  ...  14.7058   0.1158
# 4111  18.7440  0.1872  13.5351   0.0906  19.0910  ...      NaN      NaN
# 4122  16.0020  0.0155  12.1343   0.0841  15.7196  ...  11.7008   0.0632
# 4123  18.3835  0.0109  14.8322   0.0023  18.0788  ...      NaN      NaN
# 4124  19.1749  0.0216  13.6955   0.0020  17.8828  ...  14.4005   0.1119
# 4125  17.7338  0.0698  11.7686   0.0033  17.1711  ...      NaN      NaN
# 4126  21.1446  0.0872  14.8565   0.0024  18.0909  ...  19.1759   0.1799
# 4127  19.4933  0.0262  15.0018   0.0030  18.7378  ...  17.7909   0.0666
# 4129  18.6572  0.0265  12.9224   0.0849  17.9394  ...  11.9404   0.0949
# 4138  18.7732  0.0537  13.5204   0.0885  18.8689  ...      NaN      NaN
# 4139  16.9491  0.0321  11.8586   0.0465  15.6366  ...  10.6612   0.0403
# 4147  17.5523  0.0733  12.5753   0.0195  16.8155  ...      NaN      NaN
# 4149  18.8207  0.0012  13.2320   0.0220  18.5397  ...      NaN      NaN
# 4150  18.6218  0.0421  12.3393   0.0890  18.1826  ...      NaN      NaN
# 4153  19.2135  0.0066  12.8475   0.0307  20.8358  ...      NaN      NaN
# 4154  18.8050  0.0263  13.0496   0.1041  18.1397  ...      NaN      NaN
# 4156  18.3639  0.1524  13.6710   0.0471  18.0957  ...      NaN      NaN
# 4157  18.7991  0.0414  13.1610   0.1026  17.8348  ...      NaN      NaN
# 4161  18.4329  0.0109  12.4634   0.0010  17.0457  ...      NaN      NaN
# 4163  18.8950  0.0130  12.5521   0.0010  18.3947  ...      NaN      NaN
# 4164  17.9819  0.0087  12.0136   0.0010  17.3277  ...  12.9422   0.0043
# 4193  17.2860  0.0257  17.3163   0.0255  17.4246  ...  17.6043   0.0418
# 4312  18.5561  0.0322  13.2815   0.1344  18.3090  ...  16.2144   0.2369
# 4474  18.2355  0.0954  12.8832   0.0058  18.0609  ...  14.7830   0.0853
# 4482  18.7163  0.0148  12.7154   0.0011  18.2276  ...      NaN      NaN
# 4528  18.7766  0.0380  17.4863   0.0280  18.0070  ...  16.2081   0.0136
# 4538  18.1485  0.0290  16.9699   0.0084  17.1082  ...  15.2992   0.0147
# 4542  17.8588  0.0221  16.4317   0.0045  16.8051  ...  14.9052   0.0188
# 4757  15.2177  0.0024      NaN      NaN  12.7206  ...      NaN      NaN
# 6164  14.9048  0.0137  15.0473   0.0219  14.5940  ...  14.3573   0.0130
# 6169  12.6605  0.0010  12.5164   0.0010  12.3289  ...  12.2158   0.0038
# 7251  18.4087  0.0151  18.0596   0.0000  18.3148  ...      NaN      NaN
# 8159  18.8612  0.0348  16.7522   0.0051  17.9204  ...  15.9329   0.0163
# 8253  19.2743  0.0205  17.6932   0.0132  18.1557  ...  16.3625   0.0217
# 8879  18.6767  0.0302  17.5591   0.0071  17.8739  ...  16.2994   0.0157
# 9177  18.7157  0.0196  17.3431   0.0111  17.5141  ...  15.5726   0.0120
# 9248  17.8727  0.0226  16.9569   0.0080  16.8139  ...  15.2567   0.0201
# 9266  19.6704  0.0258  18.8003   0.0200  18.7569  ...      NaN      NaN
#
#            tmag               gaiaid  gaiamag  gaiadist  gaiadist_u  \
# 616   17.475882                    0      NaN       NaN         NaN
# 2082  11.953900  3904309135319776640  12.4539       NaN         NaN
# 2213  17.770054                    0      NaN       NaN         NaN
# 2910  17.152861                    0      NaN       NaN         NaN
# 2950  17.982757                    0      NaN       NaN         NaN
# 3309  17.952970                    0      NaN       NaN         NaN
# 3521  17.892229                    0      NaN       NaN         NaN
# 3885  17.893488                    0      NaN       NaN         NaN
# 4087  17.994883                    0      NaN       NaN         NaN
# 4111  17.982368                    0      NaN       NaN         NaN
# 4122  15.947400  3904332774819782272  16.4474       NaN         NaN
# 4123  17.335007                    0      NaN       NaN         NaN
# 4124  17.766734                    0      NaN       NaN         NaN
# 4125  16.872151                    0      NaN       NaN         NaN
# 4126  17.332486                    0      NaN       NaN         NaN
# 4127  17.826070                    0      NaN       NaN         NaN
# 4129  17.541802                    0      NaN       NaN         NaN
# 4138  17.538100  3904332671739847552  18.0381       NaN         NaN
# 4139  16.501300  3904332671739848192  17.0013       NaN         NaN
# 4147  16.988983                    0      NaN       NaN         NaN
# 4149  17.956188                    0      NaN       NaN         NaN
# 4150  17.613418                    0      NaN       NaN         NaN
# 4153  17.931091                    0      NaN       NaN         NaN
# 4154  17.667109                    0      NaN       NaN         NaN
# 4156  17.731399                    0      NaN       NaN         NaN
# 4157  17.213254                    0      NaN       NaN         NaN
# 4161  17.218204                    0      NaN       NaN         NaN
# 4163  17.522792                    0      NaN       NaN         NaN
# 4164  16.834776                    0      NaN       NaN         NaN
# 4193  16.872300  3904333045402009600  17.3723       NaN         NaN
# 4312  17.913291                    0      NaN       NaN         NaN
# 4474  17.682450                    0      NaN       NaN         NaN
# 4482  17.783580                    0      NaN       NaN         NaN
# 4528  17.886718                    0      NaN       NaN         NaN
# 4538  17.917500  3904336485671504768  18.4175       NaN         NaN
# 4542  17.759000  3904336485671504640  18.2590       NaN         NaN
# 4757  12.571413                    0      NaN       NaN         NaN
# 6164  14.064100  3904531644689678720  14.5641       NaN         NaN
# 6169  11.795100  3904531648985447680  12.2951       NaN         NaN
# 7251  17.902085                    0      NaN       NaN         NaN
# 8159  17.564883                    0      NaN       NaN         NaN
# 8253  17.764393                    0      NaN       NaN         NaN
# 8879  17.270849                    0      NaN       NaN         NaN
# 9177  16.910099                    0      NaN       NaN         NaN
# 9248  17.517500  3928551854883694208  18.0175       NaN         NaN
# 9266  15.882955                    0      NaN       NaN         NaN
#
#       gaiadist_l        row        col
# 616          NaN  12.004006  88.917371
# 2082         NaN  -9.804599  45.912942
# 2213         NaN  -0.661807  37.228279
# 2910         NaN  31.833332  67.308150
# 2950         NaN  22.052341  53.180036
# 3309         NaN   3.134472  36.214801
# 3521         NaN  12.192665  26.335089
# 3885         NaN  26.125678   8.629319
# 4087         NaN  40.088838  40.152653
# 4111         NaN  41.580612  40.497794
# 4122         NaN  45.452108  38.802426
# 4123         NaN  42.186921  40.865716
# 4124         NaN  44.526602  40.894082
# 4125         NaN  42.685042  40.789016
# 4126         NaN  45.086952  41.279063
# 4127         NaN  43.037801  42.045770
# 4129         NaN  41.177214  41.081532
# 4138         NaN  42.877304  41.141707
# 4139         NaN  42.785222  41.071494
# 4147         NaN  43.353688  41.262670
# 4149         NaN  44.919832  41.486644
# 4150         NaN  41.767792  40.867353
# 4153         NaN  44.692348  41.005858
# 4154         NaN  41.318077  41.434678
# 4156         NaN  41.710021  41.563905
# 4157         NaN  44.146830  40.745387
# 4161         NaN  43.420042  40.959864
# 4163         NaN  41.536578  41.182205
# 4164         NaN  43.816683  41.180548
# 4193         NaN  49.325210  59.728399
# 4312         NaN  46.593250  39.717020
# 4474         NaN  46.373301  39.092152
# 4482         NaN  45.848075  38.637050
# 4528         NaN  37.984442  22.712101
# 4538         NaN  38.630316  13.730088
# 4542         NaN  38.408728  14.226490
# 4757         NaN  67.821688  33.250219
# 6164         NaN  74.882500  -1.289559
# 6169         NaN  74.757942  -1.411137
# 7251         NaN  58.073480  87.757831
# 8159         NaN  74.585646  43.282045
# 8253         NaN  76.098349  37.567459
# 8879         NaN  85.502716  26.099529
# 9177         NaN  83.808234  10.287420
# 9248         NaN  85.977256  -0.543753
# 9266         NaN  89.033937   3.454307
#
# [46 rows x 33 columns]

# %%
tpf.wcs.all_pix2world(5,59,1)
# Out:
# [array(188.98379258), array(11.40234738)]

# %%
tpf = sd.Get_TESS(ra,dec,80,Sector = 23)

# %%
sd.Ge
# Out:
#          RA_ICRS  e_RA_ICRS    DE_ICRS  e_DE_ICRS               Source  \
# 0     189.145303     0.3354  10.769491     0.2456  3904233505240383744
# 1     189.129176     2.0262  10.765646     1.2854  3904233612614412544
# 2     189.106755     0.7122  10.770658     0.5313  3904233642679337600
# 3     189.113070     1.6428  10.768927     1.2264  3904233646974338304
# 4     189.138710     0.0355  10.782802     0.0258  3904233715694081280
# ...          ...        ...        ...        ...                  ...
# 1937  189.069680     0.0411  11.667571     0.0337  3928566182894595072
# 1938  189.072102     0.1660  11.677482     0.1274  3928566178598915072
# 1939  189.071803     0.2469  11.672818     0.1840  3928566178598913280
# 1940  189.083313     0.1398  11.678742     0.1071  3928566212958654592
# 1941  189.083750     0.5201  11.679911     0.3973  3928566212958655104
#
#          Plx   e_Plx    pmRA  e_pmRA    pmDE  ...    RPmag  e_RPmag   BP-RP  \
# 0     1.1784  0.4020   2.907   0.906  -6.673  ...  18.0786   0.0253  2.4052
# 1     0.9835  2.2443  -2.611   3.655  -3.565  ...  20.4460   0.1585  0.6156
# 2     0.8022  0.8400  -5.378   1.992  -3.443  ...  19.6038   0.1064  0.7734
# 3        NaN     NaN     NaN     NaN     NaN  ...  20.3571   0.1543  0.5753
# 4     1.0295  0.0425  17.265   0.093 -19.172  ...  14.4817   0.0018  0.9012
# ...      ...     ...     ...     ...     ...  ...      ...      ...     ...
# 1937  0.3253  0.0512  -7.290   0.106  -8.081  ...  15.1261   0.0036  0.7643
# 1938  0.3493  0.2038  -3.018   0.446  -8.024  ...  17.7694   0.0188  0.7512
# 1939 -0.0724  0.3022 -10.670   0.676  -5.582  ...  17.8664   0.0182  1.7618
# 1940  2.4991  0.1715 -11.763   0.376 -36.875  ...  16.8782   0.0057  2.3676
# 1941  2.7408  0.6453  -3.355   1.494 -91.214  ...  18.5244   0.0273  2.7911
#
#       RV  e_RV    Teff      AG  E_BP-RP_   Rad    Lum
# 0    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 2    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 3    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 4    NaN   NaN  5432.0  0.0757    0.0393  0.95  0.714
# ...   ..   ...     ...     ...       ...   ...    ...
# 1937 NaN   NaN  5872.5  1.2893    0.6373   NaN    NaN
# 1938 NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1939 NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1940 NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1941 NaN   NaN     NaN     NaN       NaN   NaN    NaN
#
# [1942 rows x 32 columns]

# %%
result.keys()
# Out:
# Index(['RA_ICRS', 'e_RA_ICRS', 'DE_ICRS', 'e_DE_ICRS', 'Source', 'Plx',
#        'e_Plx', 'pmRA', 'e_pmRA', 'pmDE', 'e_pmDE', 'Dup', 'FG', 'e_FG',
#        'Gmag', 'e_Gmag', 'FBP', 'e_FBP', 'BPmag', 'e_BPmag', 'FRP', 'e_FRP',
#        'RPmag', 'e_RPmag', 'BP-RP', 'RV', 'e_RV', 'Teff', 'AG', 'E_BP-RP_',
#        'Rad', 'Lum'],
#       dtype='object')

# %%
r2 =  sd.Get_Catalogue(tpf, Catalog = 'ps1')
r2 = r2[np.isfinite(r2.rmag) & np.isfinite(r2.imag)]# & np.isfinite(result.zmag)& np.isfinite(result.ymag)]
r2 = sd.PS1_to_TESS_mag(r2)

# %%
r2
# Out:
#           RAJ2000    DEJ2000               objID    f_objID  Qual  e_RAJ2000  \
# 1      189.142673  10.766565  120921891426760487  436527248    52     0.0697
# 4      189.160154  10.781219  120931891603447983  310456320    37     0.1877
# 7      189.149180  10.775391  120931891491251126  436527104    52     0.0599
# 9      189.180490  10.771455  120921891805426284  436527232    52     0.0435
# 11     189.154961  10.770664  120921891550725409  444674048    53     0.1135
# ...           ...        ...                 ...        ...   ...        ...
# 13780  189.020504  11.675400  122011890203751009  436527104    52     0.0404
# 13781  189.024629  11.676829  122011890246002662  436527104    52     0.1041
# 13783  189.053821  11.686243  122021890537973959  444915712    53     0.0131
# 13786  189.089380  11.689546  122021890894487919  436527104    52     0.0287
# 13787  189.092011  11.688081  122021890920346066  444915712    53     0.0560
#
#        e_DEJ2000      _tab1_10  Ns  Nd  ...  e_zmag    zKmag  e_zKmag  \
# 1         0.0386  55909.890914   5  15  ...  0.0623  21.0353   0.0561
# 4         0.0726  56509.038704   0   7  ...  0.0000  17.4835   0.0042
# 7         0.0527  55987.777477   5  20  ...  0.0809  20.8333   0.0623
# 9         0.0492  56157.581840   5  27  ...  0.0651  20.6306   0.1712
# 11        0.1135  55803.468912   4   3  ...     NaN      NaN      NaN
# ...          ...           ...  ..  ..  ...     ...      ...      ...
# 13780     0.0409  56137.761794   5  18  ...     NaN      NaN      NaN
# 13781     0.1216  56033.748773   5  10  ...     NaN      NaN      NaN
# 13783     0.0173  56055.698924   5  70  ...  0.0658  19.3224   0.0448
# 13786     0.0285  55958.323808   5  48  ...  0.1715  21.1054   0.3023
# 13787     0.0759  56025.125486   5  20  ...  0.1432  20.2433   0.1645
#
#          zFlags     ymag  e_ymag    yKmag  e_yKmag    yFlags       tmag
# 1        115000  20.1767  0.1876  20.2120   0.2746    115000        NaN
# 4      16778256  18.1583  0.0202  17.4028   0.0237  16778264  17.776670
# 7      16892216      NaN     NaN      NaN      NaN    114720  21.091710
# 9        115000  20.5461  0.1605  19.6517   0.1695    115000        NaN
# 11        16416      NaN     NaN      NaN      NaN    114720        NaN
# ...         ...      ...     ...      ...      ...       ...        ...
# 13780    114720      NaN     NaN      NaN      NaN    114720  21.396920
# 13781    114720      NaN     NaN      NaN      NaN    114720        NaN
# 13783  16892216  19.3761  0.0765  19.0010   0.0716  16892216  19.474576
# 13786    115000      NaN     NaN      NaN      NaN    114720  20.948142
# 13787  16892216      NaN     NaN      NaN      NaN    114720  21.012725
#
# [9791 rows x 36 columns]

# %%
missing = []
for i in range(len(result)):
    ra = np.isclose(result.RA_ICRS[i], r2.RAJ2000, atol=result.e_RA_ICRS[i])
    dec = np.isclose(result.DE_ICRS[i], r2.DEJ2000, atol=result.e_DE_ICRS[i])
    mag = np.isclose(result.Gmag[i]-.5, r2.tmag, atol=.1)
    if ~(ra * dec * mag).any():
        missing += [i]

# %%
missing = []
for i in range(len(result)):
    ra = np.isclose(result.RA_ICRS[i], r2.RAJ2000, atol=result.e_RA_ICRS[i])
    dec = np.isclose(result.DE_ICRS[i], r2.DEJ2000, atol=result.e_DE_ICRS[i])
    mag = np.isclose(result.Gmag[i]-.5, r2.tmag, atol=.1)
    if ~(ra * dec * mag).any():
        missing += [i]

# %%
radecs = np.vstack([result['RA_ICRS'], result['DE_ICRS']]).T
gaiacoord = tpf.wcs.all_world2pix(radecs, 1) ## TODO, is origin supposed to be zero or one?

# %%
result.iloc[missing]
# Out:
#          RA_ICRS  e_RA_ICRS    DE_ICRS  e_DE_ICRS               Source  \
# 1172  188.988297     0.0629  11.404921     0.0678  3904527697615028736
# 1174  188.988927     0.0452  11.405107     0.0453  3904527693320163712
# 1243  188.982357     0.0355  11.500555     0.0282  3904531648985447680
#
#           Plx   e_Plx     pmRA  e_pmRA    pmDE  ...    RPmag  e_RPmag   BP-RP  \
# 1172  12.5817  0.0900 -301.339   0.173 -67.994  ...   8.5224   0.0113  0.8031
# 1174  12.7726  0.0555 -301.432   0.126 -74.430  ...   8.5158   0.0045  0.7866
# 1243   2.3666  0.0440 -109.937   0.085 -26.514  ...  11.8564   0.0007  0.7190
#
#          RV  e_RV     Teff      AG  E_BP-RP_   Rad    Lum
# 1172    NaN   NaN  5804.00  0.0940    0.0450  1.06  1.150
# 1174    NaN   NaN  5880.00  0.0487    0.0237  1.04  1.158
# 1243  88.39  2.51  6178.67  0.0693    0.0320  1.10  1.579
#
# [3 rows x 32 columns]

# %%
radecs = np.vstack([r2['RAJ2000'], r2['DEJ2000']]).T
coords = tpf.wcs.all_world2pix(radecs, 1) ## TODO, is origin supposed to be zero or one?
ind = (((coords[:,0] >= -10) & (coords[:,1] >= -10)) & 
       ((coords[:,0] < (tpf.shape[1] + 10)) & (coords[:,1] < (tpf.shape[2] + 10))))
coords = coords[ind]

# %%
r2.keys()
# Out:
# Index(['RAJ2000', 'DEJ2000', 'objID', 'f_objID', 'Qual', 'e_RAJ2000',
#        'e_DEJ2000', '_tab1_10', 'Ns', 'Nd', 'gmag', 'e_gmag', 'gKmag',
#        'e_gKmag', 'gFlags', 'rmag', 'e_rmag', 'rKmag', 'e_rKmag', 'rFlags',
#        'imag', 'e_imag', 'iKmag', 'e_iKmag', 'iFlags', 'zmag', 'e_zmag',
#        'zKmag', 'e_zKmag', 'zFlags', 'ymag', 'e_ymag', 'yKmag', 'e_yKmag',
#        'yFlags', 'tmag'],
#       dtype='object')

# %%
r2 =  sd.Get_Catalogue(tpf, Catalog = 'ps1')
r2 = r2[np.isfinite(r2.rmag) & np.isfinite(r2.imag)]# & np.isfinite(result.zmag)& np.isfinite(result.ymag)]
r2 = sd.PS1_to_TESS_mag(r2)
keep = ['objID','RAJ2000', 'DEJ2000','e_RAJ2000','e_DEJ2000','gmag', 'e_gmag', 'gKmag',
       'e_gKmag', 'rmag', 'e_rmag', 'rKmag', 'e_rKmag',
       'imag', 'e_imag', 'iKmag', 'e_iKmag', 'zmag', 'e_zmag',
       'zKmag', 'e_zKmag', 'ymag', 'e_ymag', 'yKmag', 'e_yKmag',
       'tmag']
restruct = r2[keep]

# %%
for i in range(len(restruct)):
    ra = np.isclose(result.RA_ICRS, restruct.RAJ2000.iloc[i], atol=restruct.e_RAJ2000.iloc[i])
    dec = np.isclose(result.DE_ICRS, restruct.DEJ2000.iloc[i], atol=restruct.e_DEJ2000.iloc[i])
    if (ra * dec).any():
        restruct['gaiaid'] = result.Source
        restruct['gaiamag'] = result.Gmag
# Out:
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test = restruct.drop_duplicates('objID')

# %%
result.RA_ICRS.iloc[0]
# Out:
# 189.14530266477

# %%
gra = result.RA_ICRS.iloc[1]
gde = result.DE_ICRS.iloc[1]
pra = restruct.RAJ2000.values
pde = restruct.DEJ2000.values
rae = result.e_RA_ICRS.iloc[1]
dee = result.e_DE_ICRS.iloc[1]
np.isclose(gra, pra, atol=rae)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
max(gra - pra)
# Out:
# 0.4635600574300156

# %%
# Out:
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
restruct
# Out:
#                     objID     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 1      120921891426760487  189.142673  10.766565     0.0697     0.0386
# 4      120931891603447983  189.160154  10.781219     0.1877     0.0726
# 7      120931891491251126  189.149180  10.775391     0.0599     0.0527
# 9      120921891805426284  189.180490  10.771455     0.0435     0.0492
# 11     120921891550725409  189.154961  10.770664     0.1135     0.1135
# ...                   ...         ...        ...        ...        ...
# 13780  122011890203751009  189.020504  11.675400     0.0404     0.0409
# 13781  122011890246002662  189.024629  11.676829     0.1041     0.1216
# 13783  122021890537973959  189.053821  11.686243     0.0131     0.0173
# 13786  122021890894487919  189.089380  11.689546     0.0287     0.0285
# 13787  122021890920346066  189.092011  11.688081     0.0560     0.0759
#
#           gmag  e_gmag    gKmag  e_gKmag     rmag  ...     zmag  e_zmag  \
# 1          NaN     NaN      NaN      NaN  21.7825  ...  21.2540  0.0623
# 4      17.8964  0.0094  17.8044   0.0108  17.8347  ...  17.7640  0.0000
# 7      21.9732  0.2127      NaN      NaN  21.7574  ...  21.1964  0.0809
# 9          NaN     NaN      NaN      NaN  21.6880  ...  20.9132  0.0651
# 11         NaN     NaN      NaN      NaN  21.7679  ...      NaN     NaN
# ...        ...     ...      ...      ...      ...  ...      ...     ...
# 13780  21.9188  0.0678  21.8980   0.0942  21.5993  ...      NaN     NaN
# 13781      NaN     NaN      NaN      NaN  21.6109  ...      NaN     NaN
# 13783  21.4857  0.0430  21.1206   0.0513  20.2517  ...  19.5912  0.0658
# 13786  21.5955  0.0337  21.6238   0.0514  21.4189  ...  21.2886  0.1715
# 13787  22.0542  0.1857  21.5646   0.2273  21.8009  ...  21.0968  0.1432
#
#          zKmag  e_zKmag     ymag  e_ymag    yKmag  e_yKmag       tmag  gaiaid
# 1      21.0353   0.0561  20.1767  0.1876  20.2120   0.2746        NaN     NaN
# 4      17.4835   0.0042  18.1583  0.0202  17.4028   0.0237  17.776670     NaN
# 7      20.8333   0.0623      NaN     NaN      NaN      NaN  21.091710     NaN
# 9      20.6306   0.1712  20.5461  0.1605  19.6517   0.1695        NaN     NaN
# 11         NaN      NaN      NaN     NaN      NaN      NaN        NaN     NaN
# ...        ...      ...      ...     ...      ...      ...        ...     ...
# 13780      NaN      NaN      NaN     NaN      NaN      NaN  21.396920     NaN
# 13781      NaN      NaN      NaN     NaN      NaN      NaN        NaN     NaN
# 13783  19.3224   0.0448  19.3761  0.0765  19.0010   0.0716  19.474576     NaN
# 13786  21.1054   0.3023      NaN     NaN      NaN      NaN  20.948142     NaN
# 13787  20.2433   0.1645      NaN     NaN      NaN      NaN  21.012725     NaN
#
# [9791 rows x 27 columns]

# %%
restruct = r2[keep]
restruct['gaiaid'] = 0
restruct['gaiamag'] = 0
for i in range(len(result)):
    gra = result.RA_ICRS.iloc[i]
    gde = result.DE_ICRS.iloc[i]
    pra = restruct.RAJ2000.values
    pde = restruct.DEJ2000.values
    rae = result.e_RA_ICRS.iloc[i] * 10**-3
    dee = result.e_DE_ICRS.iloc[i] * 10**-3
    #print(rae)
    ra = np.isclose(gra, pra, atol=1)
    dec = np.isclose(gde, pde, atol=1)
    near = ra * dec
    if near.any():
        if sum(near) == 1:
            print('one')
            restruct['gaiaid'].iloc[near] = result.Source
            restruct['gaiamag'].iloc[near] = result.Gmag
        else:
            print('some')
            distance = np.sqrt((gra - pra)**2 + (gde - pde)**2)
            ind = np.where(np.nanmin(distance) == distance)[0]
            if len(ind) == 1:
                restruct['gaiaid'].iloc[ind] = result.Source
                restruct['gaiamag'].iloc[ind] = result.Gmag
            else:
                print('many close')
# Out:
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some
# some

# %%
sum(restruct.gaiaid.values > 0)
# Out:
# 1925

# %%
missing = []
source = result.Source.values
for i in range(len(result)):
    if (source[i] == restruct.gaiaid.values.astype(int)).any():
        missing += [i]

# %%
(int(restruct.iloc[np.isfinite(restruct.gaiaid.values)].gaiaid.iloc[0]) == restruct.gaiaid.values).any()
# Out:
# True

# %%
source
# Out:
# array([3904233505240383744, 3904233612614412544, 3904233642679337600, ...,
#        3928566178598913280, 3928566212958654592, 3928566212958655104])

# %%
plt.figure()
plt.plot(coords[:,0],coords[:,1],'.')
plt.plot(gaiacoord[missing,0],gaiacoord[missing,1],'+')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
restruct = r2[keep]
restruct['gaiaid'] = 0
restruct['gaiaid'] = restruct['gaiaid'].astype(int)
# Out:
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
restruct.gaiaid.iloc[ind]
# Out:
# 15       3904233505240383744
# 30       3904233612614412544
# 29       3904233642679337600
# 22       3904233646974338304
# 46       3904233715694081280
#                 ...
# 13760    3928566182894595072
# 13763    3928566178598915072
# 13765    3928566178598913280
# 13769    3928566212958654592
# 13764    3928566212958655104
# Name: gaiaid, Length: 1921, dtype: int64

# %%
def Unified_catalog(tpf,magnitude_limit=18,offset=10):
    """
    Find all sources present in the TESS field from PS!, and Gaia. Catalogs are cross
    matched through distance, and Gaia distances are assigned from Gaia ID.
    Returns a pandas dataframe with all relevant catalog information
    
    ------
    Input-
    ------
        tpf  lk.Targetpixelfile  target pixel file of the TESS region
        
    -------
    Output-
    -------
        result pd.DataFrame     Combined catalog
    """
    import pandas as pd
    pd.options.mode.chained_assignment = None
    # need to look at how the icrs coords are offset from J2000
    # Get gaia catalogs 
    gaia = Get_Catalogue(tpf, Catalog = 'gaia')
    gaiadist = Get_Catalogue(tpf, Catalog = 'dist')
    # Get PS1 and structure it
    ps1 = Get_Catalogue(tpf, Catalog = 'ps1')
    ps1 = ps1[np.isfinite(ps1.rmag) & np.isfinite(ps1.imag)]# & np.isfinite(result.zmag)& np.isfinite(result.ymag)]
    ps1 = sd.PS1_to_TESS_mag(ps1)
    keep = ['objID','RAJ2000', 'DEJ2000','e_RAJ2000','e_DEJ2000','gmag', 'e_gmag', 'gKmag',
           'e_gKmag', 'rmag', 'e_rmag', 'rKmag', 'e_rKmag',
           'imag', 'e_imag', 'iKmag', 'e_iKmag', 'zmag', 'e_zmag',
           'zKmag', 'e_zKmag', 'ymag', 'e_ymag', 'yKmag', 'e_yKmag',
           'tmag']
    result = ps1[keep]
    # Define the columns for Gaia information
    result['gaiaid'] = 0
    result['gaiaid'] = result['gaiaid'].astype(int)
    result['gaiamag'] = np.nan
    result['gaiadist'] = np.nan
    result['gaiadist_u'] = np.nan
    result['gaiadist_l'] = np.nan
    # Set up arrays to calculate the distance between all PS1 and Gaia sources
    dra = np.zeros((len(gaia),len(result)))
    dra = dra + gaia.RA_ICRS.values[:,np.newaxis]
    dra = dra - result.RAJ2000.values[np.newaxis,:]

    dde = np.zeros((len(gaia),len(result)))
    dde = dde + gaia.DE_ICRS.values[:,np.newaxis]
    dde = dde - result.DEJ2000.values[np.newaxis,:]
    # Calculate distance
    dist = np.sqrt(dde**2 + dra**2)
    ind = np.argmin(dist,axis=1)

    far = dist <= (1/60**2) * 1 # difference smaller than 1 arcsec
    # Get index of all valid matches and add the Gaia info
    indo = np.nansum(far,axis=1) > 0
    ind = ind[indo]
    result.gaiaid.iloc[ind] = gaia.Source.values[indo]
    result.gaiamag.iloc[ind] = gaia.Gmag.values[indo]
    # Add Gaia sources without matches to the dataframe
    keys = list(result.keys())
    indo = np.where(indo)[0]
    for i in indo:
        df = pd.DataFrame(columns=keys)
        row = np.zeros(len(keys)) * np.nan
        df.RAJ2000 = [gaia.RA_ICRS[i]]; df.DEJ2000 = [gaia.DE_ICRS[i]] 
        df.gaiaid = [gaia.Source[i]]; df.gaiamag = [gaia.Gmag[i]]
        df.tmag = [gaia.Gmag[i] - 0.5] 
        result = result.append(df,ignore_index=True)

    # Find matches from the distance catalog and add them in
    s = np.zeros((len(gaiadist),len(result)))
    s = s + gaiadist.Source.values[:,np.newaxis]
    s = s - result.gaiaid.values[np.newaxis,:]
    ind = np.where(s == 0)[1]

    result.gaiadist.iloc[ind] = gaiadist.rest
    result.gaiadist_u.iloc[ind] = gaiadist.B_rest
    result.gaiadist_l.iloc[ind] = gaiadist.b_rest
    
    result = result.iloc[result.tmag.values < magnitude_limit]
    if len(result) == 0:
        raise no_targets_found_message
    radecs = np.vstack([result['RAJ2000'], result['DEJ2000']]).T
    coords = tpf.wcs.all_world2pix(radecs, 1)
    result['row'] = coords[:,0]
    result['col'] = coords[:,1]
    #Jmag = result['Jmag']
    ind = (((coords[:,0] >= -offset) & (coords[:,1] >= -offset)) & 
           ((coords[:,0] < (tpf.shape[1] + offset)) & (coords[:,1] < (tpf.shape[2] + offset))))
    result = result.iloc[ind]
    
    return result

# %%
test = Unified_catalog(tpf)
# Out:
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:79: RuntimeWarning: invalid value encountered in less

# %%
test.tmag.values
# Out:
# array([14.45165654, 14.95748372, 15.11027022, 16.27893287, 16.4381032 ,
#        17.47588195, 15.38323452, 17.46844948, 17.61312312, 17.20495007,
#        13.97406048, 17.57997217, 14.38652791, 17.19010451, 17.2184247 ,
#        17.92331668, 15.94165835, 13.22210574, 13.84515992, 14.84865407,
#        17.34701034, 17.73581573, 16.2191414 , 12.44689351, 16.05500983,
#        16.64767499, 16.02798528, 13.87099704, 17.50170769, 15.01741158,
#        17.70866645, 17.62135431, 16.72990443, 17.77005353, 17.49107772,
#        13.19776002, 17.97708373, 13.9152416 , 13.82730246, 17.07521199,
#        17.55220794, 16.56283192, 15.51243444, 16.43328626, 17.96394627,
#        17.60919462, 17.8089649 , 14.09565275, 17.44160444, 16.39363774,
#        15.91782511, 17.79523927, 15.95974424, 11.9628856 , 17.87828863,
#        16.88847138, 16.78983195, 17.36012055, 17.44867502, 17.46192464,
#        17.29338214, 17.9371441 , 14.63956866, 17.43671488, 17.31628563,
#        17.15286108, 16.56458024, 15.56146142, 17.9827567 , 17.06464448,
#        17.62644041, 16.25258228, 17.58967959, 14.65417078, 17.0765283 ,
#        13.15588835, 13.42288891, 17.08045553, 17.79172455, 17.55469427,
#        16.24379528, 16.42819602, 15.93514107, 16.74083899, 14.83967714,
#        15.22092196, 17.95297028, 16.91383307, 17.51678459, 12.94405238,
#        13.54287642, 16.85072488, 13.96218663, 17.65982056, 17.4316721 ,
#        15.98034419, 17.5364125 , 17.19697828, 17.07606193, 16.23078424,
#        17.38674707, 16.09074022, 15.92888825, 14.63504387, 16.34139935,
#        17.77843594, 15.58288017, 17.44814225, 11.24432373, 15.41329794,
#        10.96340796, 17.8922292 , 13.62740255, 17.47745361, 13.328048  ,
#        17.76536157, 16.88711004, 17.45726036, 15.2408245 , 15.60281811,
#        17.42936711, 17.47539535, 17.94852986, 17.63262012, 13.84283891,
#        11.10999966, 15.23368779, 15.29220754, 16.54542802, 17.20442288,
#        16.9703928 , 16.24716504, 16.68722796, 14.96398541, 17.11902328,
#        15.37660024, 15.9184    , 17.86732048, 16.48079708, 17.45641038,
#        17.40948277, 12.86630124, 16.84657804, 14.10053217, 17.36070232,
#        15.7308039 , 17.94710074, 17.89348771, 16.26444095, 17.71001578,
#        15.54037175, 16.93656467, 15.84142384, 14.15250314, 17.68602333,
#        17.63398399, 17.80098581, 17.75805221, 17.36822563, 17.99488324,
#        16.73354193, 17.93332212, 17.98236789, 17.78397288, 15.18639612,
#        17.33500671, 17.76673369, 16.87215062, 17.3324862 , 17.82606991,
#        17.54180181, 16.97127868, 17.51449382, 17.28019437, 15.04715095,
#        16.98898319, 17.95618829, 17.61341843, 17.93109058, 17.66710881,
#        17.73139852, 17.21325433, 17.81652626, 17.21820431, 17.52279233,
#        16.83477574, 16.9149896 , 15.86878328, 17.1135803 , 11.28173035,
#        16.29039004, 14.15033843, 17.63755552, 14.93493887, 17.70804588,
#        16.70502161, 16.9559026 , 10.47752887, 10.47575482, 17.91329103,
#        16.06662016, 17.52293391, 17.71751521, 16.51476856, 16.63946706,
#        17.64112394, 14.29983671, 17.90217959, 15.32237775, 17.48984064,
#        16.87905501, 17.68244971, 17.87298936, 17.78357997, 15.39769827,
#        17.71717475, 17.99028777, 15.47676403, 17.93742253, 17.8867177 ,
#        16.31229525, 16.70925971, 16.48921811, 13.01394596, 13.19112511,
#        16.27441071, 16.79049931, 17.79218399, 17.68701992, 16.99396821,
#        16.66318732, 15.99882321, 17.84049305, 13.4676108 , 14.79519026,
#        17.59908252, 17.28162792, 17.5945831 , 15.13528979, 17.87823052,
#        12.5714127 , 11.49378958, 14.79864692, 16.60869105, 16.38132117,
#        17.26025762, 15.64297922, 17.56302133, 17.70721914, 17.08984402,
#        17.72992067, 16.93658055, 16.91377676, 14.38578667, 16.82543942,
#        16.57306514, 16.41861314, 15.37442423, 15.90341057, 16.0731138 ,
#        17.1885574 , 16.8255991 ,  8.4732615 , 15.8395873 ,  7.3623405 ,
#        16.8683775 , 17.57196777, 16.7558204 , 17.94230325, 14.81826978,
#        16.6638165 , 11.15253726, 17.4658275 , 16.60936047, 17.94551998,
#        11.59394989, 10.96911799, 17.97773651, 15.80855575, 16.71988832,
#        17.67024214, 17.40781521, 16.02979004, 14.86647144, 17.57092427,
#        12.14456816,  9.64663079,  9.70055392, 14.47480077, 17.77282281,
#        14.13920148, 14.75388301, 17.88652802, 17.52093301, 16.48210175,
#        17.90208549, 17.48613935, 17.74486033, 17.69076528, 17.40376449,
#        17.46473425, 17.85160778, 17.93197732, 17.86489757, 14.91308286,
#        15.49801389, 14.8069318 , 16.74166148, 15.84664415, 14.46614943,
#        16.08901293, 16.80716521, 17.58224029, 16.37125121, 12.00683952,
#        14.65924326, 14.73558266, 14.71913482, 16.63258192, 17.89032545,
#        17.17145385, 16.63612334, 17.31057387, 14.703138  , 17.23832949,
#        13.19771887, 17.47268561, 17.91678348, 17.2949801 , 15.25112288,
#        17.79750683, 16.68690447, 16.78172537, 16.37875971, 16.93691571,
#        17.73477278, 17.05127078, 16.1402552 , 14.76327007, 15.30130393,
#        17.64628415, 16.59356817, 14.57118842, 17.56488327, 15.7699145 ,
#        16.99855467, 16.44956886, 15.60969605, 15.96269082, 16.30131396,
#        17.76439284, 16.44287014, 16.79314228, 16.94018862, 17.67829074,
#        13.75004416, 17.97956388, 17.43261816, 16.75249756, 17.97019843,
#        16.2634066 , 17.9600179 , 17.27084895, 17.55436374, 17.39236809,
#        16.90136945, 16.30435131, 13.90891669, 15.42067622, 17.83473944,
#        16.91009908, 15.43051662, 17.26729351, 16.60387363, 16.2031209 ,
#        16.80808965, 15.88295474, 17.41324281, 17.19477953, 17.85802885,
#        14.3617    , 15.3988    , 15.1167    , 16.9517    , 16.6583    ,
#        15.3732    , 17.8318    , 13.8823    , 14.4247    , 17.185     ,
#        13.2905    , 15.9525    , 14.0154    , 14.9802    , 17.8861    ,
#        17.937     , 16.2703    , 11.9539    , 16.4469    , 16.4089    ,
#        17.0773    , 13.9286    , 14.9691    , 17.9557    , 17.6699    ,
#        16.9836    , 13.2634    , 13.9186    , 14.1607    , 17.0033    ,
#        17.5986    , 17.1686    , 15.5907    , 16.4521    , 17.5597    ,
#        17.7992    , 14.1007    , 16.0028    , 17.092     , 17.947     ,
#        11.9795    , 15.9454    , 16.8241    , 16.6916    , 17.6986    ,
#        14.6084    , 17.9701    , 16.4417    , 16.0122    , 17.07      ,
#        17.7016    , 16.3116    , 17.515     , 15.086     , 17.6619    ,
#        13.0949    , 13.5841    , 17.4912    , 16.2681    , 16.6975    ,
#        15.9401    , 16.3305    , 15.2629    , 14.9382    , 17.9049    ,
#        12.7571    , 16.2787    , 17.3377    , 14.4497    , 17.5917    ,
#        17.4829    , 17.3223    , 16.2653    , 17.3181    , 16.1334    ,
#        15.9153    , 14.6724    , 17.9083    , 16.3924    , 17.5778    ,
#        15.8828    , 11.3654    , 15.22      , 10.7486    , 13.5804    ,
#        17.4027    , 16.8397    , 13.3096    , 15.2784    , 15.6505    ,
#        13.8266    , 10.8545    , 15.3462    , 15.4588    , 16.2988    ,
#        17.5358    , 17.1077    , 15.6459    , 17.6351    , 15.4022    ,
#        16.3852    , 17.9543    , 16.4981    , 16.8975    , 12.9583    ,
#        14.2825    , 17.7997    , 16.3264    , 17.9498    , 16.275     ,
#        15.9982    , 17.6053    , 15.7811    , 14.3347    , 17.8231    ,
#        17.4353    , 17.0461    , 15.9474    , 16.5013    , 17.5381    ,
#        15.9683    , 16.8723    , 11.445     , 17.6405    , 16.3297    ,
#        14.7067    , 17.6307    , 14.8941    , 17.0831    , 16.8483    ,
#        10.3933    , 16.8103    , 17.1205    , 17.3866    , 14.2799    ,
#        15.3788    , 17.22      , 17.6105    , 15.8582    , 15.6036    ,
#        17.9231    , 16.2442    , 12.9918    , 17.759     , 17.9175    ,
#        12.9554    , 17.4341    , 16.9227    , 17.0959    , 17.1864    ,
#        17.7746    , 17.5979    , 16.1355    , 13.4651    , 17.9051    ,
#        14.8591    , 17.8164    , 15.4192    , 17.9196    , 11.4836    ,
#        14.8771    , 17.2399    , 16.6084    , 17.558     , 15.6939    ,
#        17.0926    , 17.8804    , 17.9923    , 17.7958    , 14.3556    ,
#        16.9723    , 16.5975    , 16.364     , 15.4167    , 16.3588    ,
#        15.9066    , 17.0487    , 17.1431    , 17.5874    ,  8.7024    ,
#        16.3624    , 16.6802    , 14.7802    , 17.1812    , 17.5592    ,
#        16.7888    , 11.6039    , 11.3931    , 16.1426    , 16.9564    ,
#        17.997     , 15.888     , 14.9693    , 17.5502    , 11.9318    ,
#        14.4645    ,  9.4676    , 17.9521    , 14.0641    , 11.7951    ,
#        17.4585    , 16.2242    , 17.5119    , 17.99      , 17.7111    ,
#        17.806     , 17.9076    , 15.145     , 15.7826    , 14.8121    ,
#        15.9835    , 17.3695    , 14.6995    , 16.5914    , 17.0086    ,
#        11.8412    , 16.3427    , 14.5595    , 14.6916    , 16.6959    ,
#        17.3147    , 17.2497    , 14.7282    , 17.718     , 17.5136    ,
#        13.1968    , 17.2417    , 15.2809    , 17.8627    , 17.3332    ,
#        16.5789    , 17.3261    , 17.2141    , 17.4994    , 16.3847    ,
#        15.2632    , 14.8161    , 14.5989    , 16.5839    , 15.8648    ,
#        17.1842    , 16.4886    , 15.9012    , 16.1152    , 16.6416    ,
#        17.0769    , 16.9177    , 17.3792    , 17.6323    , 13.9548    ,
#        17.9678    , 17.527     , 16.7221    , 17.994     , 17.3908    ,
#        16.7378    , 13.8926    , 15.3935    , 15.6734    , 17.5175    ,
#        17.0663    , 16.8088    , 17.8715    ])

# %%
keys = list(restruct.keys())

#for i in range(len(~indo)):
df = pd.DataFrame(columns=keys)

# %%
row = np.zeros(len(keys)) * np.nan
df.RAJ2000 = [result.RA_ICRS[0]]; df.DEJ2000 = [result.DE_ICRS[0]] 
df.gaiaid = [result.Source[0]]; df.gaiamag = [result.Gmag[0]]
df.tmag = [result.Gmag[0] - 0.5]

# %%
restruct = restruct.append(df,ignore_index=True)

# %%
restruct
# Out:
#                    objID     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 0     120921891426760487  189.142673  10.766565     0.0697     0.0386
# 1     120931891603447983  189.160154  10.781219     0.1877     0.0726
# 2     120931891491251126  189.149180  10.775391     0.0599     0.0527
# 3     120921891805426284  189.180490  10.771455     0.0435     0.0492
# 4     120921891550725409  189.154961  10.770664     0.1135     0.1135
# ...                  ...         ...        ...        ...        ...
# 9787  122011890246002662  189.024629  11.676829     0.1041     0.1216
# 9788  122021890537973959  189.053821  11.686243     0.0131     0.0173
# 9789  122021890894487919  189.089380  11.689546     0.0287     0.0285
# 9790  122021890920346066  189.092011  11.688081     0.0560     0.0759
# 9791                 NaN  189.145303  10.769491        NaN        NaN
#
#          gmag  e_gmag    gKmag  e_gKmag     rmag  ...     ymag  e_ymag  \
# 0         NaN     NaN      NaN      NaN  21.7825  ...  20.1767  0.1876
# 1     17.8964  0.0094  17.8044   0.0108  17.8347  ...  18.1583  0.0202
# 2     21.9732  0.2127      NaN      NaN  21.7574  ...      NaN     NaN
# 3         NaN     NaN      NaN      NaN  21.6880  ...  20.5461  0.1605
# 4         NaN     NaN      NaN      NaN  21.7679  ...      NaN     NaN
# ...       ...     ...      ...      ...      ...  ...      ...     ...
# 9787      NaN     NaN      NaN      NaN  21.6109  ...      NaN     NaN
# 9788  21.4857  0.0430  21.1206   0.0513  20.2517  ...  19.3761  0.0765
# 9789  21.5955  0.0337  21.6238   0.0514  21.4189  ...      NaN     NaN
# 9790  22.0542  0.1857  21.5646   0.2273  21.8009  ...      NaN     NaN
# 9791      NaN     NaN      NaN      NaN      NaN  ...      NaN     NaN
#
#         yKmag  e_yKmag       tmag               gaiaid  gaiamag  gaiadist  \
# 0     20.2120   0.2746        NaN                    0      NaN       NaN
# 1     17.4028   0.0237  17.776670                    0      NaN       NaN
# 2         NaN      NaN  21.091710                    0      NaN       NaN
# 3     19.6517   0.1695        NaN                    0      NaN       NaN
# 4         NaN      NaN        NaN                    0      NaN       NaN
# ...       ...      ...        ...                  ...      ...       ...
# 9787      NaN      NaN        NaN                    0      NaN       NaN
# 9788  19.0010   0.0716  19.474576                    0      NaN       NaN
# 9789      NaN      NaN  20.948142                    0      NaN       NaN
# 9790      NaN      NaN  21.012725                    0      NaN       NaN
# 9791      NaN      NaN  18.779200  3904233505240383744  19.2792       NaN
#
#       gaiadist_u  gaiadist_l
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 9787         NaN         NaN
# 9788         NaN         NaN
# 9789         NaN         NaN
# 9790         NaN         NaN
# 9791         NaN         NaN
#
# [9792 rows x 31 columns]

# %%
restruct.iloc[np.isfinite(restruct.gaiadist.values)]
# Out:
#                    objID     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 15    120921891453443918  189.145301  10.769492     0.0078     0.0041
# 29    120921891067995295  189.106756  10.770658     0.0152     0.0174
# 30    120911891292189303  189.129182  10.765644     0.0269     0.0288
# 46    120931891387179914  189.138706  10.782807     0.0055     0.0043
# 48    120951891282240374  189.128140  10.791492     0.0034     0.0031
# ...                  ...         ...        ...        ...        ...
# 1591  121061890351315737  189.035133  10.887653     0.0048     0.0035
# 1611  121061889774851250  188.977475  10.883947     0.0080     0.0020
# 1612  121061889801183115  188.980156  10.885453     0.0034     0.0018
# 1619  121071890188749700  189.018812  10.899289     0.0108     0.0079
# 1625  121061890139667511  189.013924  10.889133     0.0104     0.0057
#
#          gmag  e_gmag    gKmag  e_gKmag     rmag  ...     ymag  e_ymag  \
# 15    21.0897  0.0225  21.2597   0.0294  19.8779  ...  17.5926  0.0123
# 29    20.4608  0.0146  20.5228   0.0364  20.1819  ...  19.9621  0.0417
# 30    21.1128  0.0331  21.2460   0.0516  20.8934  ...  20.5684  0.1560
# 46    15.4270  0.0024  15.4760   0.0011  14.9794  ...  14.7485  0.0033
# 48    20.4681  0.0162  20.6066   0.0369  19.2165  ...  17.3126  0.0079
# ...       ...     ...      ...      ...      ...  ...      ...     ...
# 1591  20.5809  0.0202  20.5422   0.0646  19.3046  ...  17.3365  0.0058
# 1611  16.8165  0.0027  16.8877   0.0041  15.9940  ...  15.4576  0.0027
# 1612  16.3445  0.0032  16.4151   0.0027  15.1508  ...  13.9417  0.0014
# 1619  22.1438  0.0474  22.3082   0.0180  21.0920  ...  18.5581  0.0195
# 1625      NaN     NaN      NaN      NaN  21.2204  ...  18.5871  0.0175
#
#         yKmag  e_yKmag       tmag               gaiaid  gaiamag     gaiadist  \
# 15    17.7064   0.0167  18.035932  3904233505240383744  19.2792   553.556948
# 29    19.9827   0.1765  19.764245  3904233642679337600  20.2361   905.330948
# 30        NaN      NaN  20.431442  3904233612614412544  20.8937   683.428476
# 46    14.7779   0.0036  14.517863  3904233715694081280  15.0139  1477.189812
# 48    17.3966   0.0145  17.609177  3904233780118299264  18.7928  1320.141122
# ...       ...      ...        ...                  ...      ...          ...
# 1591  17.4226   0.0048  17.657354  3904285216646665472  18.8737  1638.746932
# 1611  15.4847   0.0050  15.345710  3904285324021085952  16.0496  1441.590457
# 1612  13.9475   0.0021  14.042256  3904285324021086080  15.0242   779.117946
# 1619  18.6471   0.0479  19.178991  3904285422805172352  20.4471  1157.880477
# 1625  18.6840   0.0315        NaN  3904285388445357696  20.4912  1817.758794
#
#        gaiadist_u   gaiadist_l
# 15     571.703204   536.508062
# 29    1650.980605   541.319467
# 30    1511.719012   296.585391
# 46    2145.034968  1074.952344
# 48    2139.807891   832.106219
# ...           ...          ...
# 1591  2499.408566  1085.669302
# 1611  2297.343465   912.999860
# 1612  1586.748085   401.746674
# 1619  2005.467911   648.020647
# 1625  2317.861836  1476.133139
#
# [198 rows x 31 columns]

# %%
plt.figure()
plt.plot(restruct.RAJ2000,restruct.DEJ2000,'.')
plt.plot(result.RA_ICRS.iloc[indo],result.DE_ICRS.iloc[indo],'r+')
plt.plot(result.RA_ICRS.iloc[~indo],result.DE_ICRS.iloc[~indo],'x')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
catalog = "I/347/gaia2dis"	
result = Vizier.query_region(c1, catalog=[catalog],
                             radius=Angle(np.max(tpf.shape[1:]) * 21, "arcsec"))

# %%
len(result[catalog])
# Out:
# 1651

# %%
dist[:,ind]
# Out:
# array([[2.57934049e-06, 1.65729753e-02, 3.85646306e-02, ...,
#         9.06313185e-01, 9.11370436e-01, 9.12514381e-01],
#        [1.65773789e-02, 6.70802358e-06, 2.29734801e-02, ...,
#         9.08985445e-01, 9.14255887e-01, 9.15408834e-01],
#        [3.85632765e-02, 2.29808502e-02, 8.37442451e-07, ...,
#         9.02837725e-01, 9.08395197e-01, 9.09559822e-01],
#        ...,
#        [9.06310743e-01, 9.08986533e-01, 9.02836591e-01, ...,
#         2.18856972e-06, 1.29492452e-02, 1.39007500e-02],
#        [9.11360109e-01, 9.14249004e-01, 9.08386200e-01, ...,
#         1.29428452e-02, 8.67476796e-06, 1.26232015e-03],
#        [9.12496959e-01, 9.15394868e-01, 9.09543771e-01, ...,
#         1.38914687e-02, 1.23975701e-03, 1.57283818e-05]])

# %%
restruct.gaiaid.iloc[ind] = result.Source.values
# Out:
# /Users/ryanr/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x = restruct.gaiaid.values > 0

# %%
restruct.iloc[x]
# Out:
#                     objID     RAJ2000    DEJ2000  e_RAJ2000  e_DEJ2000  \
# 15     120921891453443918  189.145301  10.769492     0.0078     0.0041
# 22     120921891130703192  189.113066  10.768928     0.0225     0.0182
# 29     120921891067995295  189.106756  10.770658     0.0152     0.0174
# 30     120911891292189303  189.129182  10.765644     0.0269     0.0288
# 46     120931891387179914  189.138706  10.782807     0.0055     0.0043
# ...                   ...         ...        ...        ...        ...
# 13763  122011890720813487  189.072103  11.677483     0.0074     0.0119
# 13764  122011890837616535  189.083749  11.679927     0.0100     0.0073
# 13765  122001890718127866  189.071805  11.672819     0.0038     0.0050
# 13767  122011890607360286  189.060760  11.674806     0.0217     0.0121
# 13769  122011890833265064  189.083313  11.678750     0.0095     0.0057
#
#           gmag  e_gmag    gKmag  e_gKmag     rmag  ...  e_zmag    zKmag  \
# 15     21.0897  0.0225  21.2597   0.0294  19.8779  ...  0.0078  17.9881
# 22     20.9273  0.0238  21.0864   0.0426  20.6002  ...  0.0481  20.4810
# 29     20.4608  0.0146  20.5228   0.0364  20.1819  ...  0.0151  20.1079
# 30     21.1128  0.0331  21.2460   0.0516  20.8934  ...  0.0308  21.0596
# 46     15.4270  0.0024  15.4760   0.0011  14.9794  ...  0.0019  14.8398
# ...        ...     ...      ...      ...      ...  ...     ...      ...
# 13763  18.5395  0.0044  18.6101   0.0079  18.2292  ...  0.0077  18.1250
# 13764  21.8773  0.1338  21.8774   0.2212  20.6959  ...  0.0072  18.4476
# 13765  19.7937  0.0092  19.9015   0.0141  18.7417  ...  0.0065  18.0474
# 13767  17.8827  0.0039  17.9611   0.0038  17.3763  ...  0.0057  17.1600
# 13769  19.6274  0.0067  19.7549   0.0112  18.3888  ...  0.0055  16.8515
#
#        e_zKmag     ymag  e_ymag    yKmag  e_yKmag       tmag        gaiaid  \
# 15      0.0096  17.5926  0.0123  17.7064   0.0167  18.035932  3.904234e+18
# 22      0.0785  20.7948  0.1879      NaN      NaN  20.186504  3.904234e+18
# 29      0.0384  19.9621  0.0417  19.9827   0.1765  19.764245  3.904234e+18
# 30      0.0672  20.5684  0.1560      NaN      NaN  20.431442  3.904234e+18
# 46      0.0026  14.7485  0.0033  14.7779   0.0036  14.517863  3.904234e+18
# ...        ...      ...     ...      ...      ...        ...           ...
# 13763   0.0251  18.0596  0.0243  18.0897   0.0382  17.792100  3.928566e+18
# 13764   0.0348  17.9744  0.0203  18.0625   0.0168  18.570963  3.928566e+18
# 13765   0.0142  17.8434  0.0099  17.9274   0.0484  17.853845  3.928566e+18
# 13767   0.0104  17.0763  0.0099  17.1470   0.0136  16.869580  3.928566e+18
# 13769   0.0071  16.5540  0.0060  16.6378   0.0044  16.840486  3.928566e+18
#
#        gaiamag
# 15     15.8786
# 22     19.5769
# 29     20.5180
# 30     15.3929
# 46     20.1465
# ...        ...
# 13763      NaN
# 13764      NaN
# 13765      NaN
# 13767      NaN
# 13769      NaN
#
# [1925 rows x 28 columns]

# %%
def Unified_scene(tpf, magnitude_limit = 18, Offset = 10):
    rg = sd.Get_Catalogue(tpf, Catalog = 'gaia')
    rp = sd.Get_Catalogue(tpf, Catalog = 'ps1')
    
    rp =  sd.Get_Catalogue(tpf, Catalog = 'ps1')
    rp = rp[np.isfinite(rp.rmag) & np.isfinite(rp.imag)]# & np.isfinite(result.zmag)& np.isfinite(result.ymag)]
    rp = sd.PS1_to_TESS_mag(rp)
    
    missing = []
    for i in range(len(rg)):
        ra = np.isclose(rg.RA_ICRS[i], rp.RAJ2000, atol=rg.e_RA_ICRS[i])
        dec = np.isclose(rg.DE_ICRS[i], rp.DEJ2000, atol=rg.e_DE_ICRS[i])
        mag = np.isclose(rg.Gmag[i]-.5, rp.tmag, atol=1)
        if ~(ra * dec * mag).any():
            missing += [i]

    radecs = np.vstack([rp['RAJ2000'], rp['DEJ2000']]).T
    coords = tpf.wcs.all_world2pix(radecs, 1) 
    ind = (((coords[:,0] >= -offset) & (coords[:,1] >= -offset)) & 
           ((coords[:,0] < (tpf.shape[1] + offset)) & (coords[:,1] < (tpf.shape[2] + offset))))
    coords = coords[ind]

# %%
for i in range(restruct):

# %%
from astroquery.vizier import Vizier
from astropy import units as u
from astropy.coordinates import SkyCoord, Angle

# %%
Angle()

# %%
c1 = SkyCoord(restruct.RAJ2000, restruct.DEJ2000, frame='icrs', unit='deg')
test = []

thing = Vizier.query_region(c1[7], catalog=["I/345/gaia2"],
                             radius=Angle(.5, "arcsec"))
print(len(thing))
# Out:
# 1

# %%
thing
# Out:
# TableList with 1 tables:
# 	'0:I/345/gaia2' with 32 column(s) and 1 row(s)

# %%
thing["I/345/gaia2"]
# Out:
# <Table masked=True length=1>
#     RA_ICRS     e_RA_ICRS     DE_ICRS     e_DE_ICRS ... E_BP-RP_   Rad     Lum
#       deg          mas          deg          mas    ...   mag      Rsun    Lsun
#     float64      float64      float64      float64  ... float32  float32 float64
# --------------- --------- --------------- --------- ... -------- ------- -------
# 189.14530266477    0.3354  10.76949057086    0.2456 ...       --      --      --

# %%
from astropy.coordinates import solar_system_ephemeris
from astropy.coordinates import GCRS

# %%
c1 = SkyCoord(result.RA_ICRS.iloc[0], result.DE_ICRS.iloc[0], frame='icrs', unit='deg')

# %%
with solar_system_ephemeris.set('jpl'):
    c1.transform_to(GCRS(obstime=Time("J2000")))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-175-65fde177284b> in <module>
# ----> 1 with solar_system_ephemeris.set('jpl'):
#       2     c1.transform_to(GCRS(obstime=Time("J2000")))
#       3
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/utils/state.py in set(cls, value)
#      61
#      62         ctx = _Context(cls, cls._value)
# ---> 63         value = cls.validate(value)
#      64         cls._value = value
#      65         return ctx
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/coordinates/solar_system.py in validate(cls, value)
#     110             return cls._value
#     111         # Set up Kernel; if the file is not in cache, this will download it.
# --> 112         cls.get_kernel(value)
#     113         return value
#     114
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/coordinates/solar_system.py in get_kernel(cls, value)
#     121                 cls._kernel.daf.file.close()
#     122                 cls._kernel = None
# --> 123             kernel = _get_kernel(value)
#     124             if kernel is not None:
#     125                 kernel.origin = value
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/coordinates/solar_system.py in _get_kernel(value)
#     170                           "(https://pypi.python.org/pypi/jplephem)")
#     171
# --> 172     return SPK.open(download_file(value, cache=True))
#     173
#     174
#
# ~/miniconda3/lib/python3.7/site-packages/astropy/utils/data.py in download_file(remote_url, cache, show_progress, timeout)
#    1056                             bytes_read += len(block)
#    1057                             p.update(bytes_read)
# -> 1058                             block = remote.read(conf.download_block_size)
#    1059                             if size is not None and bytes_read > size:
#    1060                                 raise urllib.error.URLError(
#
# ~/miniconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/miniconda3/lib/python3.7/http/client.py in readinto(self, b)
#     489         # connection, and the user is reading more bytes than will be provided
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#     493             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/miniconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/miniconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def Get_Catalogue(tpf, Catalog = 'gaia'):
	"""
	Get the coordinates and mag of all sources in the field of view from a specified catalogue.

	-------
	Inputs-
	-------
		tpf 				class 	target pixel file lightkurve class
		magnitude_limit 	float 	cutoff for Gaia sources
		Offset 				int 	offset for the boundary 
		Catalogue 			str 	catalogue name to query vizier 
	
	--------
	Outputs-
	--------
		coords 	array	coordinates of sources
		Gmag 	array 	Gmags of sources
	"""
	c1 = SkyCoord(tpf.ra, tpf.dec, frame='icrs', unit='deg')
	# Use pixel scale for query size
	pix_scale = 4.0  # arcseconds / pixel for Kepler, default
	if tpf.mission == 'TESS':
		pix_scale = 21.0
	# We are querying with a diameter as the radius, overfilling by 2x.
	from astroquery.vizier import Vizier
	Vizier.ROW_LIMIT = -1
	if Catalog == 'gaia':
		catalog = "I/345/gaia2"
	elif Catalog == 'dist':
		catalog = "I/347/gaia2dis"
	elif Catalog == 'ps1':
		catalog = "II/349/ps1"
	result = Vizier.query_region(c1, catalog=[catalog],
								 radius=Angle(np.max(tpf.shape[1:]) * pix_scale, "arcsec"))
	no_targets_found_message = ValueError('Either no sources were found in the query region '
										  'or Vizier is unavailable')
	#too_few_found_message = ValueError('No sources found brighter than {:0.1f}'.format(magnitude_limit))
	if result is None:
		raise no_targets_found_message
	elif len(result) == 0:
		raise no_targets_found_message
	result = result[catalog].to_pandas()
	
	return result

# %%
d = Get_Catalogue(tpf,'dist')

# %%
d
# Out:
#                    Source     RA_ICRS    DE_ICRS         rest       b_rest  \
# 0     3904233505240383744  189.145303  10.769491   843.997785   607.633220
# 1     3904233612614412544  189.129176  10.765646   926.488276   446.509906
# 2     3904233642679337600  189.106755  10.770658  1017.093558   601.623569
# 3     3904233715694081280  189.138710  10.782802   944.692135   907.957816
# 4     3904233780118299264  189.128150  10.791480   518.051586   440.999921
# ...                   ...         ...        ...          ...          ...
# 1621  3928566178598915072  189.072102  11.677482  1864.595135  1408.656629
# 1622  3928566182894595072  189.069680  11.667571  2632.970487  2328.433968
# 1623  3928566212958654592  189.083313  11.678742   397.645652   371.641170
# 1624  3928566212958655104  189.083750  11.679911   387.208660   293.411750
# 1625  3928566251614071936  189.060757  11.674804  1817.758794  1476.133139
#
#            B_rest        rlen ResFlag  ModFlag
# 0     1300.875427  460.026424    b'1'        1
# 1     1765.826212  459.952029    b'1'        1
# 2     1807.051646  459.863111    b'1'        1
# 3      984.457368  460.017077    b'1'        1
# 4      626.420780  459.984405    b'1'        1
# ...           ...         ...     ...      ...
# 1621  2570.180265  461.673177    b'1'        1
# 1622  3018.223281  461.635725    b'1'        1
# 1623   427.480868  461.723545    b'1'        1
# 1624   564.378470  461.728576    b'1'        1
# 1625  2317.861836  461.618273    b'1'        1
#
# [1626 rows x 9 columns]

# %%
d

# %%
result
# Out:
#          RA_ICRS  e_RA_ICRS    DE_ICRS  e_DE_ICRS               Source  \
# 0     189.145303     0.3354  10.769491     0.2456  3904233505240383744
# 1     189.129176     2.0262  10.765646     1.2854  3904233612614412544
# 2     189.106755     0.7122  10.770658     0.5313  3904233642679337600
# 3     189.113070     1.6428  10.768927     1.2264  3904233646974338304
# 4     189.138710     0.0355  10.782802     0.0258  3904233715694081280
# ...          ...        ...        ...        ...                  ...
# 1937  189.069680     0.0411  11.667571     0.0337  3928566182894595072
# 1938  189.072102     0.1660  11.677482     0.1274  3928566178598915072
# 1939  189.071803     0.2469  11.672818     0.1840  3928566178598913280
# 1940  189.083313     0.1398  11.678742     0.1071  3928566212958654592
# 1941  189.083750     0.5201  11.679911     0.3973  3928566212958655104
#
#          Plx   e_Plx    pmRA  e_pmRA    pmDE  ...    RPmag  e_RPmag   BP-RP  \
# 0     1.1784  0.4020   2.907   0.906  -6.673  ...  18.0786   0.0253  2.4052
# 1     0.9835  2.2443  -2.611   3.655  -3.565  ...  20.4460   0.1585  0.6156
# 2     0.8022  0.8400  -5.378   1.992  -3.443  ...  19.6038   0.1064  0.7734
# 3        NaN     NaN     NaN     NaN     NaN  ...  20.3571   0.1543  0.5753
# 4     1.0295  0.0425  17.265   0.093 -19.172  ...  14.4817   0.0018  0.9012
# ...      ...     ...     ...     ...     ...  ...      ...      ...     ...
# 1937  0.3253  0.0512  -7.290   0.106  -8.081  ...  15.1261   0.0036  0.7643
# 1938  0.3493  0.2038  -3.018   0.446  -8.024  ...  17.7694   0.0188  0.7512
# 1939 -0.0724  0.3022 -10.670   0.676  -5.582  ...  17.8664   0.0182  1.7618
# 1940  2.4991  0.1715 -11.763   0.376 -36.875  ...  16.8782   0.0057  2.3676
# 1941  2.7408  0.6453  -3.355   1.494 -91.214  ...  18.5244   0.0273  2.7911
#
#       RV  e_RV    Teff      AG  E_BP-RP_   Rad    Lum
# 0    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 2    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 3    NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 4    NaN   NaN  5432.0  0.0757    0.0393  0.95  0.714
# ...   ..   ...     ...     ...       ...   ...    ...
# 1937 NaN   NaN  5872.5  1.2893    0.6373   NaN    NaN
# 1938 NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1939 NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1940 NaN   NaN     NaN     NaN       NaN   NaN    NaN
# 1941 NaN   NaN     NaN     NaN       NaN   NaN    NaN
#
# [1942 rows x 32 columns]

# %%
np.where(3904233505240383744 == result.Source)
# Out:
# (array([0]),)
