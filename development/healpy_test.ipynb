# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

import numpy as np
import healpy as hp

# %%
NSIDE = 320
print(
    "Approximate resolution at NSIDE {} is {:.2} deg".format(
        NSIDE, hp.nside2resol(NSIDE, arcmin=True) / 60
    )
)
# Out:
# Approximate resolution at NSIDE 320 is 0.18 deg

# %%
NPIX = hp.nside2npix(NSIDE)
print(NPIX)
# Out:
# 1228800

# %%
m = np.arange(NPIX)
hp.mollview(m, title="Mollview image RING")
hp.graticule()
# Out:
# <img src="data:image/png;base64,..." width="849.9999815767466">

# %%
vec = hp.ang2vec(np.pi / 2, np.pi * 3 / 4)
print(vec)
# Out:
# [-7.07106781e-01  7.07106781e-01  6.12323400e-17]

# %%
ipix_disc = hp.query_disc(nside=320, vec=vec, radius=np.radians(10))
m = np.arange(NPIX)
m[ipix_disc] = m.max()
hp.mollview(m, title="Mollview image RING")
# Out:
# <img src="data:image/png;base64,..." width="849.9999815767466">
