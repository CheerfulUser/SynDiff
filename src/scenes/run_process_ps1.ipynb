# %%
from process_ps1 import combine_ps1

# %%
datapath = 
skycells = 
savepath = 
catalog_path =

# %%
combine_ps1(datapath, skycells, psf_std = 70, combine = [0.238,0.344,0.283,0.135], 
            catalog_path = catalog_path, savepath = savepath, suffix = 'rizy.conv',
            use_mask = True, overwrite = False, pad = 500, verbose = 0, run = True, cores = 30)
